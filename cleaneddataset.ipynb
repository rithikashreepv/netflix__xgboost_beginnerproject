# %%
import pandas as pd
df = pd.read_csv("netflix_titles.csv")
print(df.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df[df['country'].isnull()].head()
# Out:
#    show_id     type                                title  \
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
#
#                          director  \
# 2                 Julien Leclercq
# 3                             NaN
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 10                            NaN
#
#                                                  cast country  \
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 3                                                 NaN     NaN
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...     NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...     NaN
# 10                                                NaN     NaN
#
# ...

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
movies_df = df[df['type'] == 'Movie']

movies_df['country'].value_counts().head(10)
# Out:
# country
# United States     2058
# India              893
# United Kingdom     206
# Canada             122
# Spain               97
# Egypt               92
# Nigeria             86
# Indonesia           77
# Japan               76
# Turkey              76
# Name: count, dtype: int64

# %%
TV_Show_df = df[df['type'] == 'TV Show']

TV_Show_df['country'].value_counts().head(10)
# Out:
# country
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Taiwan             68
# Canada             59
# France             49
# Australia          48
# Spain              48
# Name: count, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
df['rating'].value_counts().head(10)
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: count, dtype: int64

# %%
TV_Show_df['release_year'].value_counts().head(10)
# Out:
# release_year
# 2020    436
# 2019    397
# 2018    380
# 2021    315
# 2017    265
# 2016    244
# 2015    162
# 2014     88
# 2012     64
# 2013     63
# Name: count, dtype: int64

# %%
print(df.groupby(['country', 'type']))

# %%
df.groupby(['country', 'type']).size().sort_values(ascending=False)
# Out:
# country                            type
# United States                      Movie      2058
# India                              Movie       893
# United States                      TV Show     760
# United Kingdom                     TV Show     213
#                                    Movie       206
#                                               ...
# Argentina, Uruguay, Spain, France  Movie         1
# Argentina, Uruguay, Serbia         Movie         1
# Argentina, United States, Mexico   TV Show       1
# Argentina, United States           Movie         1
# Argentina, Spain                   TV Show       1
# Length: 847, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='type', data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.countplot(x='rating', data=df)

plt.xticks(rotation=45)
plt.show()

# %%
countries = df['country'].value_counts().head(10)
countries
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
sns.barplot(x=countries.index, y=countries.values)
# Out:
# <Axes: xlabel='country'>

# %%
df['release_year'].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
year_counts = df['release_year'].value_counts().sort_index()
sns.lineplot(x=year_counts.index, y=year_counts.values)
# Out:
# <Axes: xlabel='release_year'>

# %%
df['country'] = df['country'].fillna('Unknown')
# Out:
# 0                                        United States
# 1                                         South Africa
# 2                                              Unknown
# 3                                              Unknown
# 4                                                India
# 5                                              Unknown
# 6                                              Unknown
# 7    United States, Ghana, Burkina Faso, United Kin...
# 8                                       United Kingdom
# 9                                        United States
# Name: country, dtype: object

# %%
df['director'] = df['director'].fillna('Unknown')
df['rating'] = df['rating'].fillna('Unknown')
df['duration'] = df['duration'].fillna('0')
df['cast'] = df['cast'].fillna('cast')
df['date_added'] = df['date_added'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
